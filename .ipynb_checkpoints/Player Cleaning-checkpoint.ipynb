# %%
import pandas as pd

path = "CleanPlayerData.csv"
data = pd.read_csv(path)
data.head()
# Out:
#        person Alignment fOutcome Hit1 HitL HitNum Death Inactive GM Mod Spec  \
# 0        Meta         0        0    -    -      -   NaN        N  Y   N    N
# 1    Cracknut         G        L  1.0  1.0    1.0     E        N  N   N    N
# 2  Edgedancer         G        L  2.0  2.0    1.0     L        N  N   N    N
# 3   Mailliw73         G        L  4.0  4.0    1.0     L        N  N   N    N
# 4      Aether         E        W  4.0  4.0    1.0     V        N  N   N    N
#
#   gtype  GameNum Game Broken     Role
# 0    LG      1.0  LG1      N       GM
# 1    LG      1.0  LG1      N   Tineye
# 2    LG      1.0  LG1      N      Cop
# 3    LG      1.0  LG1      N  Regular
# 4    LG      1.0  LG1      N   Smoker

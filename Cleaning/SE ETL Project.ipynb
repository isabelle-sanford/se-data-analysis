# %%
# imports
import pandas as pd

import sqlalchemy
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

# %% [markdown]
# ## PART 1: EXTRACT
#
# source: https://docs.google.com/spreadsheets/d/1CxrgdT4Xd8J0N3CuVmkVRryMeIdm93H8rzv8-YlP0kw/
#
# FURTHER WORK:
# Web scraping info - 17S turnovers? Votes? GM sheets? Player post counts?
#
# Add Sheets API pull to automate

# %% [markdown]
# *Player data ('Data Test' tab)*

# %%
player_path = "../datacsvs/DataTest.csv"
playerdata = pd.read_csv(player_path)
playerdata.head()
# Out:
#    ID      Player Alignment Faction Outcome  First Hit  Last Hit  # of Hits  \
# 0   1        Meta       NaN             NaN        NaN       NaN        NaN
# 1   2    Cracknut         G               L        1.0       1.0        1.0
# 2   3  Edgedancer         G               L        2.0       2.0        1.0
# 3   4   Mailliw73         G               L        4.0       4.0        1.0
# 4   5      Aether         E               W        4.0       4.0        1.0
#
#   Death/\n Survival Inactive   GM  ... Broken     Role  \
# 0               NaN      NaN    Y  ...    NaN       GM
# 1                 E      NaN  NaN  ...    NaN   Tineye
# 2                 L      NaN  NaN  ...    NaN      Cop
# 3                 L      NaN  NaN  ...    NaN  Regular
# 4                 V      NaN  NaN  ...    NaN   Smoker
#
#                            Unnamed: 17  Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0  Roles that are unique and don't fit          NaN  Unfinished   Alignment
# 1                MR1/LG8/MR7 need work          NaN         QF7           0
# 2                                  NaN          NaN         MR6           0
# 3                                  NaN          NaN        LG12           0
# 4                                  NaN          NaN         QF8           0
#
#   Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24
# 0     Victory        Hits    Survival         NaN
# 1           0          13           0         NaN
# 2           0          25           0         NaN
# 3           0           2           0         NaN
# 4           0          22           0         NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# *Game data ('Game Stats' tab)*

# %%
game_path = "../datacsvs/GameStats.csv"
gamedata = pd.read_csv(game_path)
gamedata.head()
# Out:
#         Game Stats Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0              NaN        LG1        LG2        LG3        LG4        QF1
# 1     # of Players         16         29         22         30         12
# 2       Total Rank        132         16         59         13        166
# 3  # of Spectators          3          2          5          1         11
# 4             Rank         85         97         65        118         37
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 169 Unnamed: 170  \
# 0        LG5        MR1        LG6        QF2  ...         LG69         QF47
# 1         20         27         25         15  ...          NaN          NaN
# 2         84         29         43        140  ...          NaN          NaN
# 3          2          4          5          9  ...          NaN          NaN
# 4         97         73         65         44  ...          NaN          NaN
#
#   Unnamed: 171 Unnamed: 172 Unnamed: 173 Unnamed: 174 Unnamed: 175  \
# 0         LG70         MR45         LG71         QF48         MR46
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 176 Unnamed: 177 Unnamed: 178
# 0         LG72         QF49         MR47
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN
#
# [5 rows x 179 columns]

# %% [markdown]
# ## PART 2: TRANSFORM
#
# *FURTHER WORK:*
#
# 1) Reduce/flatten non-player data into mod/spec/GM tables
#
# 2) Remove game data that can be produced by aggregating player data
#
# 3) Game data - split 'LG1' etc into two separate columns
#
# 4) Deal with blanks in Hit columns and convert to numerical types
#
# 5) Flatten further by giving players an ID and putting them somewhere else; provide tables that are basically keys for alignment, outcome, etc to clarify what they mean (?)

# %% [markdown]
# ### 2A: Player data
# *Initial cleaning*

# %%
playerdata.columns
# Out:
# Index(['ID', 'Player', 'Alignment', 'Faction Outcome', 'First Hit', 'Last Hit',
#        '# of Hits', 'Death/\n Survival', 'Inactive', 'GM', 'Mod', 'Spec',
#        'Game Type', 'Game #', 'Unnamed: 14', 'Broken', 'Role', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24'],
#       dtype='object')

# %%
# Select useful columns (last few are irrelevant)
pdata = playerdata[["Player", "Alignment", "Faction Outcome", "First Hit", "Last Hit", "# of Hits", 
             "Death/\n Survival", "Inactive", 'GM', 'Mod', 'Spec', 'Game Type', 'Game #', 
             'Unnamed: 14', 'Broken', 'Role']]

# Rename columns for accuracy or simplicity
pdata = pdata.rename(columns = {"Player": "person",
                                "Faction Outcome": "fOutcome", 
                                "First Hit": "Hit1", 
                                "Last Hit": "HitL",
                                "# of Hits": "HitNum", 
                                "Death/\n Survival": "Death", 
                                "Game Type": "gtype",
                                "Game #": "GameNum", 
                                "Unnamed: 14": "Game"})

# %%
# Fill in NaN values
pdata = pdata.fillna({"Alignment": 0, 
                       "fOutcome": 0, 
                      "Hit1": "-", 
                      "HitL": "-", 
                      "HitNum": "-", 
                      "Inactive":"N", 
                      "GM":"N", 
                      "Mod": "N", 
                      "Spec": "N", 
                      "Broken": "N", 
                      "Role": "-"})
print(len(pdata))
pdata.head()
# Out:
# 5763
#        person Alignment fOutcome Hit1 HitL HitNum Death Inactive GM Mod Spec  \
# 0        Meta         0        0    -    -      -   NaN        N  Y   N    N
# 1    Cracknut         G        L    1    1      1     E        N  N   N    N
# 2  Edgedancer         G        L    2    2      1     L        N  N   N    N
# 3   Mailliw73         G        L    4    4      1     L        N  N   N    N
# 4      Aether         E        W    4    4      1     V        N  N   N    N
#
#   gtype  GameNum Game Broken     Role
# 0    LG      1.0  LG1      N       GM
# 1    LG      1.0  LG1      N   Tineye
# 2    LG      1.0  LG1      N      Cop
# 3    LG      1.0  LG1      N  Regular
# 4    LG      1.0  LG1      N   Smoker

# %%
# separate out mod/spec/GM into separate table

# get indices of all non-players
nonplayers_list = []
it = pdata.iterrows()
i = 0
while i != 5672:
    curr = next(it)
    
    ifmod = curr[1]["Mod"]
    ifGM = curr[1]["GM"]
    ifspec = curr[1]["Spec"]
    
    if (ifmod == "Y") or (ifGM == "Y") or (ifspec == "Y"):
        nonplayers_list.append(curr[0])
    
    i += 1

print(len(nonplayers_list))

# @TODO: SIMPLIFY etc
# Out:
# 1445

# %%
# pull relevant columns and filter by index list above
nonplayers = pdata.filter(["person", "GM", "Mod", "Spec", "gtype", "GameNum", "Game", "Broken"], axis = 1)
nonplayers = nonplayers.filter(nonplayers_list, axis = 0)

nonplayers.head()
nonplayers.to_csv("../datacsvs/NonPlayerData.csv", index = False)

# to clean further: combine GM/mod/spec into one column, don't need 'Game' probably
# Maybe separate into separate GM/Mod/Spec tables?

# %%
# take out nonplayers to create players dataframe
playerlist = [j for j in range(5763) if j not in nonplayers_list]

players = pdata.filter(playerlist, axis = 0)
players = players.drop(['GM', 'Mod', 'Spec'], axis = 1)

players.head()
players.to_csv("../datacsvs/CleanPlayerData.csv", index = False)

# %% [markdown]
# ### 2B: Game data

# %%
gamedata.head()
# Out:
#         Game Stats Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0              NaN        LG1        LG2        LG3        LG4        QF1
# 1     # of Players         16         29         22         30         12
# 2       Total Rank        132         16         59         13        166
# 3  # of Spectators          3          2          5          1         11
# 4             Rank         85         97         65        118         37
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 169 Unnamed: 170  \
# 0        LG5        MR1        LG6        QF2  ...         LG69         QF47
# 1         20         27         25         15  ...          NaN          NaN
# 2         84         29         43        140  ...          NaN          NaN
# 3          2          4          5          9  ...          NaN          NaN
# 4         97         73         65         44  ...          NaN          NaN
#
#   Unnamed: 171 Unnamed: 172 Unnamed: 173 Unnamed: 174 Unnamed: 175  \
# 0         LG70         MR45         LG71         QF48         MR46
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 176 Unnamed: 177 Unnamed: 178
# 0         LG72         QF49         MR47
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN
#
# [5 rows x 179 columns]

# %%
gdata0 = gamedata.fillna('NA')

# need to transpose entire thing and set first column to be the column headers
# this is a MESS
# maybe when getting data initially, read 1 row first and then feed to pandas? solves header problem partly

cols = gdata0["Game Stats"]

cols
# Out:
# 0                  NA
# 1        # of Players
# 2          Total Rank
# 3     # of Spectators
# 4                Rank
#            ...
# 73            Faction
# 74               Draw
# 75       Free For All
# 76             No One
# 77               Misc
# Name: Game Stats, Length: 78, dtype: object

# %%
cols[0] = "Game"
cols[2] = 'PlayerNumRank'
cols[4] = 'SpecNumRank'
cols
# Out:
# 0                Game
# 1        # of Players
# 2       PlayerNumRank
# 3     # of Spectators
# 4         SpecNumRank
#            ...
# 73            Faction
# 74               Draw
# 75       Free For All
# 76             No One
# 77               Misc
# Name: Game Stats, Length: 78, dtype: object

# %%
gdata1 = gdata0.transpose()

gdata2 = gdata1.rename(columns = cols)

gdata2.head()
# Out:
#             Game  # of Players  PlayerNumRank  # of Spectators  SpecNumRank  \
# Game Stats  Game  # of Players  PlayerNumRank  # of Spectators  SpecNumRank
# Unnamed: 1   LG1            16            132                3           85
# Unnamed: 2   LG2            29             16                2           97
# Unnamed: 3   LG3            22             59                5           65
# Unnamed: 4   LG4            30             13                1          118
#
#             # of E. Kills  # of Neutral Evil Kils  # of V. Kills  \
# Game Stats  # of E. Kills  # of Neutral Evil Kils  # of V. Kills
# Unnamed: 1              5                       0              1
# Unnamed: 2             14                       0              2
# Unnamed: 3              3                       0              1
# Unnamed: 4              4                       0              4
#
#             # of Lynches  # of FF Deaths  ...  Faction/Free For All  NA  NA  \
# Game Stats  # of Lynches  # of FF Deaths  ...  Faction/Free For All  NA  NA
# Unnamed: 1             4               0  ...                    NA  NA  NA
# Unnamed: 2             7               2  ...                    NA  NA  NA
# Unnamed: 3             7               3  ...                    NA  NA  NA
# Unnamed: 4             8               4  ...                    NA  NA  NA
#
#             Eliminator  Village  Faction  Draw  Free For All  No One  Misc
# Game Stats  Eliminator  Village  Faction  Draw  Free For All  No One  Misc
# Unnamed: 1          NA       NA       NA    NA            NA      NA    NA
# Unnamed: 2          NA       NA       NA    NA            NA      NA    NA
# Unnamed: 3          NA       NA       NA    NA            NA      NA    NA
# Unnamed: 4          NA       NA       NA    NA            NA      NA    NA
#
# [5 rows x 78 columns]

# %%
gdata2 = gdata2.reset_index(drop = True)

# %%
gdata2.columns

gdata3 = gdata2[['Game', '# of Players', 'Total Rank', '# of Spectators', 'Rank',
       '# of E. Kills', '# of Neutral Evil Kils', '# of V. Kills',
       '# of Lynches', '# of FF Deaths', '# of Neutral Deaths',
       '# of Inactive Deaths', '# of Deaths', 'Rank', '# of Eliminators',
       'Eliminator Percentage', 'Eliminators Lynched', "Eliminators Vig'd",
       'Thread Reply Count', 'Thread Reply Rank', 'Setting', 'Game Complexity',
       '# of Cycles', 'Winning Team', '# of Survivors', 'Total Rank',
       'Survivors']]

gdata3.head()
# Out:
#    Game  # of Players  Total Rank  # of Spectators  Rank  # of E. Kills  \
# 0  Game  # of Players  Total Rank  # of Spectators  Rank  # of E. Kills
# 1   LG1            16          86                3   121              5
# 2   LG2            29          49                2     5             14
# 3   LG3            22         112                5    67              3
# 4   LG4            30         123                1    23              4
#
#    # of Neutral Evil Kils  # of V. Kills  # of Lynches  # of FF Deaths  ...  \
# 0  # of Neutral Evil Kils  # of V. Kills  # of Lynches  # of FF Deaths  ...
# 1                       0              1             4               0  ...
# 2                       0              2             7               2  ...
# 3                       0              1             7               3  ...
# 4                       0              4             8               4  ...
#
#    Eliminators Vig'd  Thread Reply Count  Thread Reply Rank  Setting  \
# 0  Eliminators Vig'd  Thread Reply Count  Thread Reply Rank  Setting
# 1                  1                 462                 79  Cosmere
# 2                  2               1,232                 11  Cosmere
# 3                  1                 739                 41  Cosmere
# 4                  4               1,029                 22  Cosmere
#
#    Game Complexity  # of Cycles  Winning Team  # of Survivors  Total Rank  \
# 0  Game Complexity  # of Cycles  Winning Team  # of Survivors  Total Rank
# 1            Basic            4    Eliminator               6          86
# 2         Standard           11    Eliminator               4          49
# 3            Basic            7       Village               8         112
# 4         Standard            9       Village               9         123
#
#    Survivors
# 0  Survivors
# 1    Claincy
# 2     Aether
# 3       Meta
# 4  Mailliw73
#
# [5 rows x 27 columns]

# %%
gdata3 = gdata3.drop(0, axis = 0)
gdata3.head()

# TODO: split 'Game' into # and format
gdata3.to_csv('../datacsvs/CleanGameData.csv')

# %%
gdata3.tail()
# Out:
#      Game # of Players Total Rank # of Spectators Rank # of E. Kills  \
# 174  QF48           NA         NA              NA   NA            NA
# 175  MR46           NA         NA              NA   NA            NA
# 176  LG72           NA         NA              NA   NA            NA
# 177  QF49           NA         NA              NA   NA            NA
# 178  MR47           NA         NA              NA   NA            NA
#
#     # of Neutral Evil Kils # of V. Kills # of Lynches # of FF Deaths  ...  \
# 174                     NA            NA           NA             NA  ...
# 175                     NA            NA           NA             NA  ...
# 176                     NA            NA           NA             NA  ...
# 177                     NA            NA           NA             NA  ...
# 178                     NA            NA           NA             NA  ...
#
#     Eliminators Vig'd Thread Reply Count Thread Reply Rank Setting  \
# 174                NA                 NA                NA      NA
# 175                NA                 NA                NA      NA
# 176                NA                 NA                NA      NA
# 177                NA                 NA                NA      NA
# 178                NA                 NA                NA      NA
#
#     Game Complexity # of Cycles Winning Team # of Survivors Total Rank  \
# 174              NA          NA           NA             NA         NA
# 175              NA          NA           NA             NA         NA
# 176              NA          NA           NA             NA         NA
# 177              NA          NA           NA             NA         NA
# 178              NA          NA           NA             NA         NA
#
#     Survivors
# 174        NA
# 175        NA
# 176        NA
# 177        NA
# 178        NA
#
# [5 rows x 27 columns]

# %% [markdown]
# ### 2C: Analysis & Graphs
# TODO: pull data from SQL pls

# %%
pnums = gdata3['# of Players'].replace(to_replace = 'NA', value = '0').astype(int)

# %%
import matplotlib.pyplot as plt

# NUMBER OF PLAYERS PER GAME OVER TIME
fig, ax = plt.subplots()
ax.scatter(range(len(pnums)), pnums)

# %%
# NUMBER OF PLAYERS OVER TIME, SEPARATED BY FORMAT

players.head()

formats = players.groupby('gtype')

formats.count()
# Out:
#        person  Alignment  fOutcome  Hit1  HitL  HitNum  Death  Inactive  \
# gtype
# AG        181        181       181   181   181     181    181       181
# LG       1664       1664      1664  1664  1664    1664   1555      1664
# MR        923        923       923   923   923     923    894       923
# QF        928        928       928   928   928     928    880       928
#
#        GameNum  Game  Broken  Role
# gtype
# AG         181   181     181   181
# LG        1664  1664    1664  1664
# MR         923   923     923   923
# QF         928   928     928   928

# %%
formatnums = formats['GameNum'].value_counts(sort = False)

formatnums

fn1 = pd.DataFrame(formatnums)
fn1 = fn1.rename(columns = {'GameNum': 'Game #'})
fn2 = fn1.reset_index()

# %%
lgnums = players[players['gtype'] == "LG"]['GameNum'].value_counts(sort = False)
mrnums = players[players['gtype'] == "MR"]['GameNum'].value_counts(sort = False)
qfnums = players[players['gtype'] == "QF"]['GameNum'].value_counts(sort = False)

# %%
fig1, (ax1, ax2, ax3) = plt.subplots(ncols = 3, figsize = (15, 5))
ax1.scatter(lgnums.index, lgnums)
ax2.scatter(mrnums.index, mrnums)
ax3.scatter(qfnums.index, qfnums);

# %%
fig1, ax1 = plt.subplots()
ax1.scatter(lgnums.index, lgnums)
ax1.scatter(mrnums.index, mrnums)
ax1.scatter(qfnums.index, qfnums);

# %% [markdown]
# ## PART 3: LOAD
# FURTHER WORK:
#
# 1) Get SQLAlchemy classes working to play with data
#
# 2) Analyze from SQL data; create aggregations that mimic Main/GameStats/etc
#
# 3) Create a Flask app or site to display visualizations. Interactive?

# %%
# Create Engine for census data
path = "../GameData.sqlite"
engine = create_engine(f"sqlite:///{path}")
conn = engine.connect()

# %%
players.reset_index().to_sql("player", con = conn, if_exists = 'replace')

# %%
nonplayers.reset_index().to_sql("nonplayer", con = conn, if_exists = 'replace')

# %%
gdata3.reset_index().to_sql("game", con = conn, if_exists = 'replace')

# %% [markdown]
# THE END
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
#
# for now

# %%
# TODO: Set up classes for easy addition of rows; figure out easy updating; put pretty things into Flask

# %%
# Import and establish Base for which classes will be constructed 
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# Import modules to declare columns and column data types
from sqlalchemy import Column, Integer, String, Float

# %%
nonplayers.head()
# Out:
#     person GM Mod Spec gtype  GameNum Game Broken
# 0     Meta  Y   N    N    LG      1.0  LG1      N
# 17   Windy  N   N    Y    LG      1.0  LG1      N
# 18   Weiry  N   N    Y    LG      1.0  LG1      N
# 19  Alvron  N   N    Y    LG      1.0  LG1      N
# 20    Meta  Y   N    N    LG      2.0  LG2      N

# %%
session = Session(bind=engine)
    
class Player(Base):
    __tablename__ = 'player'
    index = Column(Integer, primary_key = True)
    person = Column(String(255))
    Alignment = Column(String(255))
    fOutcome = Column(String(255))
    Hit1 = Column(String(255)) # FOR NOW 
    HitL = Column(String(255))
    Death = Column(String(255))
    Inactive = Column(String(255))
    gtype = Column(String(255))
    GameNum = Column(Float)
    Game = Column(String(255))
    Broken = Column(String(255))
    Role = Column(String(255))

# %%
from sqlalchemy import and_, or_, func
from sqlalchemy.orm import Query
from sqlalchemy.dialects import sqlite

# %%
# weights = (
#     Query(Player)
#     #.join(X, X.player_id = BaseballPlayer.player_id) or whatever
#     .filter(and_(birth_year < 1990, birth_country == "USA"))
#     .with_session(session)
#     .with_entities(BaseballPlayer.birth_country,
#                    func.min(BaseballPlayer.weight)) 
#     .group_by(BaseballPlayer.birth_country) #
#     .all()
# )

# weights

# %%
me = (
    Query(Player)
    .filter(Player.person == "Elbereth")
    .with_session(session)
    .with_entities(Player.Game, Player.fOutcome)
    .all()
)

me
# Out:
# [('LG15.1', 'L'),
#  ('LG15.2', 'W'),
#  ('MR10', 'L'),
#  ('AG2', 'L'),
#  ('QF12', 'L'),
#  ('LG16', 'W'),
#  ('MR11', 'W'),
#  ('LG17', 'W'),
#  ('QF13', 'W'),
#  ('LG18', 'W'),
#  ('MR12', 'W'),
#  ('QF14', 'D'),
#  ('LG20', 'L'),
#  ('QF15', 'W'),
#  ('LG21', 'L'),
#  ('LG22', 'W'),
#  ('QF16', 'W'),
#  ('LG23', 'W'),
#  ('MR15', 'W'),
#  ('LG24', 'L'),
#  ('QF17', 'L'),
#  ('MR16', 'W'),
#  ('MR17', 'L'),
#  ('LG27', 'D'),
#  ('QF19', 'W'),
#  ('LG28', 'L'),
#  ('MR18', 'L'),
#  ('AG3', 'L'),
#  ('LG30', 'L'),
#  ('QF22', 'L'),
#  ('QF23', 'W'),
#  ('LG35', 'W'),
#  ('MR23', 'W'),
#  ('LG37', 'D'),
#  ('LG39', 'L'),
#  ('LG43', 'L'),
#  ('LG46', 'L'),
#  ('QF39', 'L'),
#  ('LG60', 'L'),
#  ('QF40.1', 'L'),
#  ('QF40.2', 'L'),
#  ('LG61', 'W'),
#  ('LG62', 'W'),
#  ('QF44', 'W'),
#  ('LG67', 'L'),
#  ('MR43', 'L')]
